# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
f=pd.read_csv('D:/Ibbibanz/Python/Loan Prediction Dataset.csv')
f
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
f.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
f.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
import matplotlib
# %matplotlib inline

# %%
f.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
f.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
f['LoanAmount'] = f['LoanAmount'].fillna(f['LoanAmount'].mean())
f['Loan_Amount_Term'] = f['Loan_Amount_Term'].fillna(f['Loan_Amount_Term'].mean())
f['Credit_History'] = f['Credit_History'].fillna(f['Credit_History'].mean())

# %%
f['Gender'] = f["Gender"].fillna(f['Gender'].mode()[0])
f['Married'] = f["Married"].fillna(f['Married'].mode()[0])
f['Dependents'] = f["Dependents"].fillna(f['Dependents'].mode()[0])
f['Self_Employed'] = f["Self_Employed"].fillna(f['Self_Employed'].mode()[0])

# %%
f.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
sb.countplot(f['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sb.countplot(f['Married'])
# Out:
# <Axes: xlabel='count', ylabel='Married'>

# %%
sb.countplot(f['Dependents'])
# Out:
# <Axes: xlabel='count', ylabel='Dependents'>

# %%
sb.countplot(f['Education'])
# Out:
# <Axes: xlabel='count', ylabel='Education'>

# %%
sb.countplot(f['Self_Employed'])
# Out:
# <Axes: xlabel='count', ylabel='Self_Employed'>

# %%
sb.countplot(f['Property_Area'])
# Out:
# <Axes: xlabel='count', ylabel='Property_Area'>

# %%
sb.countplot(f['Loan_Status'])
# Out:
# <Axes: xlabel='count', ylabel='Loan_Status'>

# %%
sb.distplot(f["ApplicantIncome"])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\1936792927.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f["ApplicantIncome"])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
sb.distplot(f["CoapplicantIncome"])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\2402390025.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f["CoapplicantIncome"])
# <Axes: xlabel='CoapplicantIncome', ylabel='Density'>

# %%
sb.distplot(f["LoanAmount"])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\4156432634.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f["LoanAmount"])
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
sb.distplot(f['Loan_Amount_Term'])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\927248328.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f['Loan_Amount_Term'])
# <Axes: xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
sb.distplot(f['Credit_History'])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\4094711035.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f['Credit_History'])
# <Axes: xlabel='Credit_History', ylabel='Density'>

# %%
f['Total_Income'] = f['ApplicantIncome'] + f['CoapplicantIncome']
f.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income
# 0             1.0         Urban           Y        5849.0
# ...

# %%
f['ApplicantIncomeLog'] = np.log(f['ApplicantIncome']+1)
sb.distplot(f["ApplicantIncomeLog"])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\490232895.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f["ApplicantIncomeLog"])
# <Axes: xlabel='ApplicantIncomeLog', ylabel='Density'>

# %%
f['CoapplicantIncomeLog'] = np.log(f['CoapplicantIncome']+1)
sb.distplot(f["CoapplicantIncomeLog"])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\1385356410.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f["CoapplicantIncomeLog"])
# <Axes: xlabel='CoapplicantIncomeLog', ylabel='Density'>

# %%
f['LoanAmountLog'] = np.log(f['LoanAmount']+1)
sb.distplot(f["LoanAmountLog"])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\1319495082.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f["LoanAmountLog"])
# <Axes: xlabel='LoanAmountLog', ylabel='Density'>

# %%
f['Loan_Amount_Term_Log'] = np.log(f['Loan_Amount_Term']+1)
sb.distplot(f["Loan_Amount_Term_Log"])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\3100291481.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f["Loan_Amount_Term_Log"])
# <Axes: xlabel='Loan_Amount_Term_Log', ylabel='Density'>

# %%
f['Total_Income_Log'] = np.log(f['Total_Income']+1)
sb.distplot(f["Total_Income_Log"])
# Out:
# C:\Users\91882\AppData\Local\Temp\ipykernel_62008\4213261472.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(f["Total_Income_Log"])
# <Axes: xlabel='Total_Income_Log', ylabel='Density'>

# %%
corr = f.corr()
plt.figure(figsize=(15,10))
sb.heatmap(corr, annot = True, cmap="BuPu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 corr = f.corr()
#       2 plt.figure(figsize=(15,10))
#       3 sb.heatmap(corr, annot = True, cmap="BuPu")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
# ...

# %%
cols = ['ApplicantIncome', 'CoapplicantIncome', "LoanAmount", "Loan_Amount_Term", "Total_Income", 'Loan_ID', 'CoapplicantIncomeLog']
f = f.drop(columns=cols, axis=1)
f.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0         Urban           Y            8.674197       4.993232
# 1         Rural           N            8.430327       4.859812
# 2         Urban           Y            8.006701       4.204693
# 3         Urban           Y            7.857094       4.795791
# 4         Urban           Y            8.699681       4.955827
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 0              5.888878          8.674197
# 1              5.888878          8.714732
# ...

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Gender',"Married","Education",'Self_Employed',"Property_Area","Loan_Status","Dependents"]
le = LabelEncoder()
for col in cols:
    f[col] = le.fit_transform(f[col])

# %%
X = f.drop(columns=['Loan_Status'], axis=1)
y = f['Loan_Status']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.model_selection import cross_val_score
def classify(model, x, y):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    model.fit(x_train, y_train)
    print("Accuracy is", model.score(x_test, y_test)*100)
    score = cross_val_score(model, x, y, cv=5)
    print("Cross validation is",np.mean(score)*100)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model, X, y)
# Out:
# Accuracy is 77.27272727272727
# Cross validation is 80.9462881514061

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model, X, y)
# Out:
# Accuracy is 74.02597402597402
# Cross validation is 72.4750099960016

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
model = RandomForestClassifier()
classify(model, X, y)
# Out:
# Accuracy is 78.57142857142857
# Cross validation is 79.64814074370253

# %%
model = ExtraTreesClassifier()
classify(model, X, y)
# Out:
# Accuracy is 74.67532467532467
# Cross validation is 77.20245235239238

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=25, max_depth=7, max_features=1)
classify(model, X, y)
# Out:
# Accuracy is 76.62337662337663
# Cross validation is 80.78368652538984

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[25, 29],
#        [ 3, 97]])

# %%
sb.heatmap(cm, annot=True)
# Out:
# <Axes: >
