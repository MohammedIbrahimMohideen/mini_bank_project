# %%
import numpy as np
import pandas as pd
mf=pd.read_csv("D:/Ibbibanz/Python/carprices.csv")
mf
# Out:
#          Car Model  Mileage  Sell Price  Age
# 0           BMW X5    69000       18000    6
# 1           BMW X5    35000       34000    3
# 2           BMW X5    57000       26100    5
# 3           BMW X5    22500       40000    2
# 4           BMW X5    46000       31500    4
# 5             Audi    59000       29400    5
# 6             Audi    52000       32000    5
# 7             Audi    72000       19300    6
# 8             Audi    91000       12000    8
# 9   Mercedez Benz     67000       22000    6
# 10  Mercedez Benz     83000       20000    7
# 11  Mercedez Benz     79000       21000    7
# 12  Mercedez Benz     59000       33000    5
# 13          Toyota    51000       42000    4
# 14          Toyota    65000       32000    7
# 15          Toyota    39000       55000    5

# %%
mf.head()
# Out:
#   Car Model  Mileage  Sell Price  Age
# 0    BMW X5    69000       18000    6
# 1    BMW X5    35000       34000    3
# 2    BMW X5    57000       26100    5
# 3    BMW X5    22500       40000    2
# 4    BMW X5    46000       31500    4

# %%
dummies = pd.get_dummies(mf['Car Model'])
dummies
# Out:
#      Audi  BMW X5  Mercedez Benz   Toyota
# 0   False    True           False   False
# 1   False    True           False   False
# 2   False    True           False   False
# 3   False    True           False   False
# 4   False    True           False   False
# 5    True   False           False   False
# 6    True   False           False   False
# 7    True   False           False   False
# 8    True   False           False   False
# 9   False   False            True   False
# 10  False   False            True   False
# 11  False   False            True   False
# 12  False   False            True   False
# 13  False   False           False    True
# 14  False   False           False    True
# 15  False   False           False    True

# %%
merge = pd.concat([mf,dummies],axis='columns')
merge
# Out:
#          Car Model  Mileage  Sell Price  Age   Audi  BMW X5  Mercedez Benz   \
# 0           BMW X5    69000       18000    6  False    True           False
# 1           BMW X5    35000       34000    3  False    True           False
# 2           BMW X5    57000       26100    5  False    True           False
# 3           BMW X5    22500       40000    2  False    True           False
# 4           BMW X5    46000       31500    4  False    True           False
# 5             Audi    59000       29400    5   True   False           False
# 6             Audi    52000       32000    5   True   False           False
# 7             Audi    72000       19300    6   True   False           False
# 8             Audi    91000       12000    8   True   False           False
# 9   Mercedez Benz     67000       22000    6  False   False            True
# 10  Mercedez Benz     83000       20000    7  False   False            True
# ...

# %%
final.columns
# Out:
# Index(['Mileage', 'Sell Price', 'Age', 'Audi', 'BMW X5', 'Mercedez Benz ',
#        'Toyota'],
#       dtype='object')

# %%
predictors = ['Mileage','Age','Audi','BMW X5','Mercedez Benz ','Toyota']
x = final[predictors]
y = final['Sell Price']

# %%
x.shape,y.shape
# Out:
# ((16, 6), (16,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 ,random_state =43)
x_train.shape,x_test.shape
# Out:
# ((12, 6), (4, 6))

# %%
reg = LinearRegression()
model = reg.fit(x_train,y_train)
model.predict([[69000,6,0,1,0,0]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([19691.37462078])

# %%
model.score(x_test,y_test)
# Out:
# 0.811689917168813

# %%
model.score(x_train,y_train)
# Out:
# 0.9588077853742554

# %%
import matplotlib.pyplot as plt
plt.plot(mf['Age'], mf['Mileage'])
plt.xlabel('Age')
plt.ylabel('Mileage')
plt.show()

# %%
plt.bar(mf['Age'], mf['Mileage'])
plt.xlabel('Age')
plt.ylabel('Mileage')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(mf['Age'], labels=mf['Mileage'], autopct='%2.1f%%')
plt.title('Age Vs Mileage ')
plt.show()

# %%
import numpy as np
import pandas as pd
af=pd.read_csv("D:/Ibbibanz/Python/Assignment-2_Data.csv")
af
# Out:
#           Id    age           job   marital  education default  balance  \
# 0       1001  999.0    management   married   tertiary      no   2143.0
# 1       1002   44.0    technician    single  secondary      no     29.0
# 2       1003   33.0  entrepreneur   married  secondary      no      2.0
# 3       1004   47.0   blue-collar   married    unknown      no   1506.0
# 4       1005   33.0       unknown    single    unknown      no      1.0
# ...      ...    ...           ...       ...        ...     ...      ...
# 45206  46207   51.0    technician   married   tertiary      no    825.0
# 45207  46208   71.0       retired  divorced    primary      no   1729.0
# 45208  46209   72.0       retired   married  secondary      no   5715.0
# 45209  46210   57.0   blue-collar   married  secondary      no    668.0
# 45210  46211   37.0  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
j = pd.get_dummies(af['job'])
j
# Out:
#        admin.  blue-collar  entrepreneur  housemaid  management  retired  \
# 0       False        False         False      False        True    False
# 1       False        False         False      False       False    False
# 2       False        False          True      False       False    False
# 3       False         True         False      False       False    False
# 4       False        False         False      False       False    False
# ...       ...          ...           ...        ...         ...      ...
# 45206   False        False         False      False       False    False
# 45207   False        False         False      False       False     True
# 45208   False        False         False      False       False     True
# 45209   False         True         False      False       False    False
# 45210   False        False          True      False       False    False
#
#        self-employed  services  student  technician  unemployed  unknown
# ...

# %%
k = pd.concat([af,j],axis='columns')
k
# Out:
#           Id    age           job   marital  education default  balance  \
# 0       1001  999.0    management   married   tertiary      no   2143.0
# 1       1002   44.0    technician    single  secondary      no     29.0
# 2       1003   33.0  entrepreneur   married  secondary      no      2.0
# 3       1004   47.0   blue-collar   married    unknown      no   1506.0
# 4       1005   33.0       unknown    single    unknown      no      1.0
# ...      ...    ...           ...       ...        ...     ...      ...
# 45206  46207   51.0    technician   married   tertiary      no    825.0
# 45207  46208   71.0       retired  divorced    primary      no   1729.0
# 45208  46209   72.0       retired   married  secondary      no   5715.0
# 45209  46210   57.0   blue-collar   married  secondary      no    668.0
# 45210  46211   37.0  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  ...  entrepreneur housemaid  management  \
# ...

# %%
p=k.drop(['job'],axis='columns')
p.columns
# Out:
# Index(['Id', 'age', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y', 'admin.', 'blue-collar', 'entrepreneur',
#        'housemaid', 'management', 'retired', 'self-employed', 'services',
#        'student', 'technician', 'unemployed', 'unknown'],
#       dtype='object')

# %%
predictors = ['Id', 'age', 'balance','day', 'duration']
x = p[predictors]
y = p['balance']

# %%
x.shape,y.shape
# Out:
# ((45211, 5), (45211,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 ,random_state =43)
x_train.shape,x_test.shape
# Out:
# ((36168, 5), (9043, 5))

# %%
reg = LinearRegression()
model = reg.fit(x_train,y_train)
model.predict([[69000,6,0,1,0,0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 reg = LinearRegression()
# ----> 2 model = reg.fit(x_train,y_train)
#       3 model.predict([[69000,6,0,1,0,0]])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:618, in LinearRegression.fit(self, X, y, sample_weight)
#     614 n_jobs_ = self.n_jobs
#     616 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# ...
